# %%
pip install ultralytics opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO
import cv2

# %%
# Load model
model = YOLO("yolov8s.pt")

# %% [markdown]
# ### image detection

# %%
# Read image
img = cv2.imread(r"C:\Users\RAKESH\Downloads\Object detection project\detect(1).jpg")

# %%
# Perform detection
results = model(img)
# Out:
# 0: 384x640 8 persons, 1 bicycle, 2 buss, 2 trucks, 1 traffic light, 96.7ms
# Speed: 2.0ms preprocess, 96.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
# ======================================
# Show Detection Image
# ======================================

output = results[0].plot()

cv2.imshow("Image Detection", output)

cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
# ======================================
# Extract Detection Data
# ======================================

for result in results:

    for box in result.boxes:

        # Class ID
        class_id = int(box.cls[0])

        # Object Name
        class_name = result.names[class_id]

        # Confidence Score
        confidence = float(box.conf[0])

        # Bounding Box Coordinates
        x1, y1, x2, y2 = box.xyxy[0]

        # Print Detection Details
        print("Object:", class_name)

        print("Confidence:", round(confidence, 2))

        print("Coordinates:",
              int(x1),
              int(y1),
              int(x2),
              int(y2))

        print("-" * 30)
# Out:
# Object: bus
# Confidence: 0.93
# Coordinates: 154 64 376 322
# ------------------------------
# Object: person
# Confidence: 0.82
# Coordinates: 304 238 353 352
# ------------------------------
# Object: person
# Confidence: 0.79
# Coordinates: 103 211 137 347
# ------------------------------
# Object: person
# Confidence: 0.74
# Coordinates: 49 223 79 316
# ------------------------------
# Object: person
# Confidence: 0.74
# Coordinates: 133 212 177 369
# ------------------------------
# Object: person
# Confidence: 0.73
# Coordinates: 18 222 45 292
# ------------------------------
# Object: bicycle
# Confidence: 0.62
# Coordinates: 314 284 353 355
# ------------------------------
# Object: traffic light
# Confidence: 0.6
# Coordinates: 100 9 143 115
# ------------------------------
# Object: truck
# Confidence: 0.54
# Coordinates: 464 162 767 379
# ------------------------------
# Object: truck
# Confidence: 0.47
# Coordinates: 369 151 505 329
# ------------------------------
# ...

# %% [markdown]
# ### Video Detection

# %%
# Open video
cap = cv2.VideoCapture(r"C:\Users\RAKESH\Downloads\Object detection project\Adobe Express - Adobe Express - vidssave.com Before YOLO object detection (Input Video) 480P (online-video-cutter.com) (1).mp4")

# Check video
if not cap.isOpened():
    print("Cannot open video")
    exit()

print("Press Q to quit")

# ==========================================
# Video Loop
# ==========================================

while True:

    ret, frame = cap.read()

    if not ret:
        print("Video completed")
        break

    # Perform detection
    results = model(frame)

   

    # ======================================
    # Draw detections
    # ======================================

    output = results[0].plot()

    # Show video
    cv2.imshow("Video Detection", output)

    # Quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()

cv2.destroyAllWindows()
# Out:
# Press Q to quit
#
# 0: 640x384 1 person, 3 cars, 1 motorcycle, 137.1ms
# Speed: 9.7ms preprocess, 137.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 1 motorcycle, 108.5ms
# Speed: 4.3ms preprocess, 108.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 1 motorcycle, 98.7ms
# Speed: 3.2ms preprocess, 98.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 1 motorcycle, 99.1ms
# Speed: 1.8ms preprocess, 99.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 1 motorcycle, 91.4ms
# Speed: 2.1ms preprocess, 91.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 1 motorcycle, 104.6ms
# Speed: 1.8ms preprocess, 104.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 1 motorcycle, 103.3ms
# ...

# %%
    # ======================================
    # Extract detection data
    # ======================================

    for result in results:

        for box in result.boxes:

            # Class ID
            class_id = int(box.cls[0])

            # Class name
            class_name = result.names[class_id]

            # Confidence score
            confidence = float(box.conf[0])

            # Bounding box coordinates
            x1, y1, x2, y2 = box.xyxy[0]

            # Print detection data
            print("Object:", class_name)

            print("Confidence:", round(confidence, 2))

            print("Coordinates:",
                  int(x1),
                  int(y1),
                  int(x2),
                  int(y2))
            

            print("-" * 30)
# Out:
# Object: car
# Confidence: 0.93
# Coordinates: 498 594 718 812
# ------------------------------
# Object: truck
# Confidence: 0.76
# Coordinates: 236 585 293 634
# ------------------------------
# Object: person
# Confidence: 0.66
# Coordinates: 25 586 83 698
# ------------------------------
# Object: truck
# Confidence: 0.63
# Coordinates: 120 578 159 627
# ------------------------------
# Object: motorcycle
# Confidence: 0.58
# Coordinates: 26 639 79 709
# ------------------------------
# Object: car
# Confidence: 0.54
# Coordinates: 287 1133 674 1281
# ------------------------------
# Object: car
# Confidence: 0.38
# Coordinates: 508 602 545 632
# ------------------------------
# Object: car
# Confidence: 0.34
# Coordinates: 98 593 119 609
# ------------------------------
# Object: traffic light
# Confidence: 0.26
# Coordinates: 391 451 403 476
# ------------------------------

# %% [markdown]
# ### Live Webcam Object Detection + Extract Data

# %%
# Open webcam
cap = cv2.VideoCapture(0)

# Check webcam
if not cap.isOpened():
    print("Cannot open webcam")
    exit()

print("Webcam opened successfully")
print("Press Q to quit")

while True:

    # Read frame
    ret, frame = cap.read()

    if not ret:
        print("Failed to read frame")
        break

    # Perform detection
    results = model.predict(frame, conf=0.5)

    # Plot results
    annotated_frame = results[0].plot()

    # Show output
    cv2.imshow("YOLOv8 Detection", annotated_frame)

    # Quit button
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# Webcam opened successfully
# Press Q to quit
#
# 0: 480x640 1 person, 215.9ms
# Speed: 1.5ms preprocess, 215.9ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.1ms
# Speed: 3.0ms preprocess, 324.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.2ms
# Speed: 1.4ms preprocess, 215.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 275.7ms
# Speed: 13.7ms preprocess, 275.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)

# %%
# ======================================
# Extract Detection Data
# ======================================

for result in results:

    for box in result.boxes:

        # Class ID
        class_id = int(box.cls[0])

        # Object Name
        class_name = result.names[class_id]

        # Confidence Score
        confidence = float(box.conf[0])

        # Bounding Box Coordinates
        x1, y1, x2, y2 = box.xyxy[0]

        # Print Data
        print("Object:", class_name)

        print("Confidence:", round(confidence, 2))

        print("Coordinates:",
              int(x1),
              int(y1),
              int(x2),
              int(y2))

        print("-" * 30)
# Out:
# Object: person
# Confidence: 0.93
# Coordinates: 150 138 600 479
# ------------------------------
